# %% [markdown]
# ### Config stuff

# %%
import random
import pyspark
from pyspark.sql import SparkSession, functions
import ConnectionConfig as cc
from pyspark.sql.functions import *
cc.setupEnvironment()
cc.listEnvironment()
# Out:
# ALLUSERSPROFILE: C:\ProgramData
# APPDATA: C:\Users\lzkol\AppData\Roaming
# COMMONPROGRAMFILES: C:\Program Files\Common Files
# COMMONPROGRAMFILES(X86): C:\Program Files (x86)\Common Files
# COMMONPROGRAMW6432: C:\Program Files\Common Files
# COMPUTERNAME: LIZA
# COMSPEC: C:\WINDOWS\system32\cmd.exe
# DRIVERDATA: C:\Windows\System32\Drivers\DriverData
# EFC_12428_1262719628: 1
# EFC_12428_1592913036: 1
# EFC_12428_2775293581: 1
# EFC_12428_3789132940: 1
# FPS_BROWSER_APP_PROFILE_STRING: Internet Explorer
# FPS_BROWSER_USER_PROFILE_STRING: Default
# GOPATH: C:\Users\lzkol\go
# HOMEDRIVE: C:
# HOMEPATH: \Users\lzkol
# IPY_INTERRUPT_EVENT: 2068
# JAVA_HOME: C:\Program Files\Java\jdk-11\
# JPY_INTERRUPT_EVENT: 2068
# JPY_PARENT_PID: 2156
# JPY_SESSION_NAME: DWH_dimUser_velo_initial.ipynb
# LANG: en_US.UTF-8
# LANGUAGE:
# LC_ALL: en_US.UTF-8
# LOCALAPPDATA: C:\Users\lzkol\AppData\Local
# LOGONSERVER: \\LIZA
# NUMBER_OF_PROCESSORS: 16
# ONEDRIVE: C:\Users\lzkol\OneDrive
# OS: Windows_NT
# PATH: C:\Users\lzkol\PycharmProjects\sparkdelta\.venv\Scripts;C:\Program Files\Common Files\Oracle\Java\javapath;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\Program Files\PuTTY\;C:\Program Files\Git\cmd;C:\Program Files\Docker\Docker\resources\bin;C:\Program Files\Go\bin;C:\Users\lzkol\AppData\Local\Programs\Python\Launcher\;C:\Users\lzkol\AppData\Local\Microsoft\WindowsApps;C:\Users\lzkol\AppData\Local\JetBrains\Toolbox\scripts;;C:\Users\lzkol\AppData\Local\Microsoft\WindowsApps;C:\Users\lzkol\go\bin;C:\Users\lzkol\AppData\Local\Programs\Microsoft VS Code\bin;C:\bigdatatools\bigdatatools\spark-3.5.2-bin-hadoop3\bin;C:\bigdatatools\bigdatatools\hadoop-3.4.0-win10-x64\bin;C:\Program Files\Java\jdk-11\bin;C:\bigdatatools\bigdatatools\spark-3.5.2-bin-hadoop3\bin;C:\bigdatatools\bigdatatools\hadoop-3.4.0-win10-x64\bin;C:\Program Files\Java\jdk-11\bin
# PATHEXT: .COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC
# PROCESSOR_ARCHITECTURE: AMD64
# PROCESSOR_IDENTIFIER: AMD64 Family 25 Model 68 Stepping 1, AuthenticAMD
# PROCESSOR_LEVEL: 25
# PROCESSOR_REVISION: 4401
# PROGRAMDATA: C:\ProgramData
# PROGRAMFILES: C:\Program Files
# PROGRAMFILES(X86): C:\Program Files (x86)
# PROGRAMW6432: C:\Program Files
# PROMPT: (.venv) $P$G
# PSMODULEPATH: C:\Program Files\WindowsPowerShell\Modules;C:\WINDOWS\system32\WindowsPowerShell\v1.0\Modules
# PUBLIC: C:\Users\Public
# PYTHONPATH: C:\Users\lzkol\PycharmProjects\sparkdelta;C:/Users/lzkol/AppData/Local/Programs/PyCharm Professional/plugins/python-ce/helpers/pydev;C:/Users/lzkol/AppData/Local/Programs/PyCharm Professional/plugins/python/helpers-pro/jupyter_debug
# SESSIONNAME: Console
# SYSTEMDRIVE: C:
# SYSTEMROOT: C:\WINDOWS
# TEMP: C:\Users\lzkol\AppData\Local\Temp
# TMP: C:\Users\lzkol\AppData\Local\Temp
# USERDOMAIN: LIZA
# USERDOMAIN_ROAMINGPROFILE: LIZA
# USERNAME: lzkol
# USERPROFILE: C:\Users\lzkol
# VBOX_MSI_INSTALL_PATH: C:\Program Files\Oracle\VirtualBox\
# VIRTUAL_ENV: C:\Users\lzkol\PycharmProjects\sparkdelta\.venv
# WINDIR: C:\WINDOWS
# _OLD_VIRTUAL_PATH: C:\Program Files\Common Files\Oracle\Java\javapath;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\Program Files\PuTTY\;C:\Program Files\Git\cmd;C:\Program Files\Docker\Docker\resources\bin;C:\Program Files\Go\bin;C:\Users\lzkol\AppData\Local\Programs\Python\Launcher\;C:\Users\lzkol\AppData\Local\Microsoft\WindowsApps;C:\Users\lzkol\AppData\Local\JetBrains\Toolbox\scripts;;C:\Users\lzkol\AppData\Local\Microsoft\WindowsApps;C:\Users\lzkol\go\bin;C:\Users\lzkol\AppData\Local\Programs\Microsoft VS Code\bin
# _OLD_VIRTUAL_PROMPT: $P$G
# PYDEVD_USE_FRAME_EVAL: NO
# TERM: xterm-color
# CLICOLOR: 1
# FORCE_COLOR: 1
# CLICOLOR_FORCE: 1
# PAGER: cat
# GIT_PAGER: cat
# MPLBACKEND: module://matplotlib_inline.backend_inline
# PYSPARK_PYTHON: python
# SPARK_HOME: C:\bigdatatools\bigdatatools\spark-3.5.2-bin-hadoop3
# HADOOP_HOME: C:\bigdatatools\bigdatatools\hadoop-3.4.0-win10-x64
# PYSPARK_HADOOP_VERSION: 3

# %%
spark = cc.startLocalCluster("dimUser")
spark.getActiveSession()
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.65.95:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>dimUser</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Creating the operational database
# In order to run this demo you have to create a tutorial_op database and run the PostgreSQL_SalesOperational.sql script.

# %% [markdown]
# # Initial load
# We will create a slowly changing dimension type 2 called dimSalesRep based on a sourceTable in our operational database called dbo.salesrep. SCD2  tables demand extra care and  because we will store hirstorical values of the dimension with the help of ranges.
# This notebook will create the table and fill it with the initial data. A second notebook will be used for increments of new and changed data.
#
# This is an example of the expected output (salesRepSK is different
# ```
# +----------+-------------+-------------+-----------+-------------------+-------------------+--------------------+-------+
# |salesRepID|         name|       office| salesRepSK|          scd_start|            scd_end|                 md5|current|
# +----------+-------------+-------------+-----------+-------------------+-------------------+--------------------+-------+
# |a46add1...|      Z. Jane|     New York|          0|1990-01-01 00:00:00|2100-12-12 00:00:00|303db545462092a92...|   true|
# |s1fedf1...|   P. Chapman|       Berlin|          1|1990-01-01 00:00:00|2100-12-12 00:00:00|14b094c31bf9e4149...|   true|
# |d5e6f77...|     T. Crane|     New York|          2|1990-01-01 00:00:00|2100-12-12 00:00:00|6c062f95defda9dc3...|   true|
# ```

# %%
cc.set_connectionProfile("velodb")

df_operational_sales_rep = spark.read \
    .format("jdbc") \
    .option("driver" , cc.get_Property("driver")) \
    .option("url", cc.create_jdbc()) \
    .option("dbtable", "velo_users") \
    .option("user", cc.get_Property("username")) \
    .option("password", cc.get_Property("password")) \
    .option("partitionColumn", "userid") \
    .option("numPartitions", 4) \
    .option("lowerBound", 0) \
    .option("upperBound", 20) \
    .load()

#Method 1 : Use the DataFrame API
#df_dim_sales_rep = df_sales_rep.withColumn("salesRepSK", expr("uuid()")) \
#    .withColumn("scd_start", lit("1990-01-01").cast("timestamp")) \
#    .withColumn("scd_end", lit("2100-12-12").cast("timestamp")) \
#    .withColumn("md5", md5(concat( col('name'), col('office')))) \
#    .withColumn("current", lit(True))

# Method 2 : Use SQL
df_operational_sales_rep.createOrReplaceTempView("velo_users")
df_dim_users = spark.sql("select *, uuid() as SK, to_timestamp('1999-01-01','yyyy-MM-dd') as scd_start, to_timestamp('2100-12-12','yyyy-MM-dd') as scd_end, md5(concat(street, number, zipcode, city, country_code)) as md5, True as current from velo_users")

df_dim_users.printSchema()
df_dim_users.show()
df_dim_users.write.format("delta").mode("overwrite").saveAsTable("dimUser")

#spark.sql("ALTER TABLE dimSalesRep  ADD columns (salesRepSK long GENERATED ALWAYS AS IDENTITY (START WITH 0 INCREMENT BY 1)")
# Out:
# root
#  |-- userid: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- street: string (nullable = true)
#  |-- number: string (nullable = true)
#  |-- zipcode: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- country_code: string (nullable = true)
#  |-- SK: string (nullable = false)
#  |-- scd_start: timestamp (nullable = true)
#  |-- scd_end: timestamp (nullable = true)
#  |-- md5: string (nullable = true)
#  |-- current: boolean (nullable = false)
#
# +------+--------------------+--------------------+--------------------+--------+-------+--------------------+------------+--------------------+-------------------+-------------------+--------------------+-------+
# |userid|                name|               email|              street|  number|zipcode|                city|country_code|                  SK|          scd_start|            scd_end|                 md5|current|
# +------+--------------------+--------------------+--------------------+--------+-------+--------------------+------------+--------------------+-------------------+-------------------+--------------------+-------+
# |     1|         Bouman Lars|Lars.Bouman@gmail...|         Somméstraat|    156 |   2060|           Antwerpen|          BE|3cdf3883-e195-4df...|1999-01-01 00:00:00|2100-12-12 00:00:00|fddd2c34acf178b1f...|   true|
# |     2|   van der Zee Julia|Julia.van.der.Zee...|          Europalaan|     43 |   2610| Wilrijk (Antwerpen)|          BE|8891cdf4-6da3-495...|1999-01-01 00:00:00|2100-12-12 00:00:00|e91f35aa29e5d732f...|   true|
# |     3|     de Boer Ricardo|Ricardo.de.Boer@g...|   Maria Clarastraat|     80 |   2160|           Wommelgem|          BE|8dfbdad8-90cb-446...|1999-01-01 00:00:00|2100-12-12 00:00:00|5372c35ac3d3a8b04...|   true|
# |     4|      Willems Angela|Angela.Willems@te...|Graaf Joseph de P...|     15 |   2900|             Schoten|          BE|fcd53ba1-034a-4a5...|1999-01-01 00:00:00|2100-12-12 00:00:00|92680e7e5a3c54a58...|   true|
# |     5|    Heijnen Patricia|Patricia.Heijnen@...|          Meylstraat|    111 |   2540|                Hove|          BE|6860e873-126a-47a...|1999-01-01 00:00:00|2100-12-12 00:00:00|48ea9f32068a93fbe...|   true|
# |     6|      Driessen Anouk|Anouk.Driessen@sc...|   Jan Ockegemstraat|168 0107|   2650|              Edegem|          BE|e2b684bb-dcd7-4fd...|1999-01-01 00:00:00|2100-12-12 00:00:00|706882038769b7fd0...|   true|
# |     7|      Dijkstra Frank|Frank.Dijkstra@sc...|        Klamperdreef|    154 |   2900|             Schoten|          BE|9eb02569-8a7a-452...|1999-01-01 00:00:00|2100-12-12 00:00:00|ed370331b0fcb12d4...|   true|
# |     8|  den Hartog Suzanne|Suzanne.den.Harto...|      Kolibriestraat|138 0608|   2170| Merksem (Antwerpen)|          BE|1597965f-82ac-4b3...|1999-01-01 00:00:00|2100-12-12 00:00:00|f485183bb9a7d886c...|   true|
# |     9|            Smit Tim|  Tim.Smit@gmail.com|       Bikschotelaan|     60 |   2600| Berchem (Antwerpen)|          BE|26535dd6-5966-49b...|1999-01-01 00:00:00|2100-12-12 00:00:00|fd41f6e42aef717ff...|   true|
# |    10|van der Steen Carmen|Carmen.van.der.St...|          Benzineweg|    137 |   2020|           Antwerpen|          BE|32332d8c-84c6-4b9...|1999-01-01 00:00:00|2100-12-12 00:00:00|4b98d1f4be8e5efe5...|   true|
# |    11| de Ruijter Daniëlle|Daniëlle.de.Ruijt...|      Leo Metsstraat| 21 0905|   2070|  Burcht/Zwijndrecht|          BE|d50e3d8c-2b30-401...|1999-01-01 00:00:00|2100-12-12 00:00:00|925b88578674b3a61...|   true|
# |    12|        Simons Thijs|Thijs.Simons@outl...|         Bergenhoeve| 81 0302|   2040|Antwerpen/Berendr...|          BE|3aed6a95-5a0c-4b5...|1999-01-01 00:00:00|2100-12-12 00:00:00|c0a171e8c75d85887...|   true|
# |    13|          Groen Rens|Rens.Groen@outloo...|  Trompetvogelstraat|      1 |   2170| Merksem (Antwerpen)|          BE|f22df2c5-b6ae-408...|1999-01-01 00:00:00|2100-12-12 00:00:00|223acb6ce3d6de00e...|   true|
# |    14|   van der Veer Romy|Romy.van.der.Veer...|Prosper De Vochtlaan|    177 |   2550|    Kontich/Waarloos|          BE|0a2300b0-37b9-490...|1999-01-01 00:00:00|2100-12-12 00:00:00|75bacd20bbc29c8f3...|   true|
# |    15|           Hoek Emma|Emma.Hoek@telenet.be|    John Kennedylaan|  9 0801|   2520|Broechem/Emblem/O...|          BE|b9cca001-f6f3-4fc...|1999-01-01 00:00:00|2100-12-12 00:00:00|6e3779642d13bf4ab...|   true|
# |    16|     Stevens Suzanne|Suzanne.Stevens@t...|              Wijk 2| 19 0802|   2531|              Vremde|          BE|5ce1a392-4f37-4b1...|1999-01-01 00:00:00|2100-12-12 00:00:00|81dec6ab4f1b91eef...|   true|
# |    17|van den Bosch Rutger|Rutger.van.den.Bo...|       Schoggestraat|     73 |   2100|  Deurne (Antwerpen)|          BE|9585f2de-8543-4fd...|1999-01-01 00:00:00|2100-12-12 00:00:00|f4b825db3b59e9970...|   true|
# |    18|      Veldman Angela|Angela.Veldman@gm...|Emiel Van Hemeldo...|     93 |   2540|                Hove|          BE|61e98aaa-9036-4c2...|1999-01-01 00:00:00|2100-12-12 00:00:00|319ef7ee26c646ab2...|   true|
# |    19|     Bakker Daniëlle|Daniëlle.Bakker@s...|            Fortbaan|     88 |   2160|           Wommelgem|          BE|fa8a3ef7-7a6d-47c...|1999-01-01 00:00:00|2100-12-12 00:00:00|ccc59a80114fbf09b...|   true|
# |    20|      Vink Elisabeth|Elisabeth.Vink@gm...|  Joseph Wateletlaan|100 0403|   2160|           Wommelgem|          BE|af3d1540-b9ba-483...|1999-01-01 00:00:00|2100-12-12 00:00:00|aa838917117b89e28...|   true|
# +------+--------------------+--------------------+--------------------+--------+-------+--------------------+------------+--------------------+-------------------+-------------------+--------------------+-------+
# only showing top 20 rows

# %% [markdown]
# * The function lit() is used when you want a fixed column value for every row. In this case scd_start, scd_end and current.
# * The function md5() performs a md5-hash function on the preferred columns. This is needed to detect scd2 changes. When one of the included columns changes, the md5-hash will change. Include all SCD2 columns in the md5-hash function.

# %% [markdown]
# ## Delete the spark session

# %%
spark.stop()
